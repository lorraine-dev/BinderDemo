# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Create some simple random data
np.random.seed(42)
group1 = np.random.normal(10, 2, 30)
group2 = np.random.normal(12, 2, 30)

# %%
# Conduct a t-test
t_stat, p_value = stats.ttest_ind(group1, group2)

# Display results
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: -4.512913234547555
# P-value: 3.176506547470154e-05

# %%
# Simple plot
plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'])
plt.title('Group 1 vs Group 2')
plt.ylabel('Values')
plt.show()
# Out:
# /var/folders/8s/x1c25_p16b7777lcyb6__3fm0000gn/T/ipykernel_4894/1476530855.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2], labels=['Group 1', 'Group 2'])
